# %% [markdown]
# <a href="https://colab.research.google.com/github/maitrey3196/matrix96/blob/master/DAY1AI_adhoc_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
#loading matplotlib library
import matplotlib.pyplot as plt

# %%
x=[2,9,3,7]
y=[7,15,5,9]
plt.xlabel("Distance") # x axis
plt.ylabel("Time") # y label
plt.plot(x,y,label="railway track") #this will draw a line
plt.scatter(x,y,s=200,label="railway station",marker='*',color='red') #this will plot scatter plot and s is the size marker to replace * over dot
#plt.bar(x,y,label='height of railway station')
plt.pie(scores,labels=players,explode=(0.2,0,0,0),shadow=True,autopct='%1.1ff%%')# autopct to show percentage
#plt.grid(color='red')
plt.legend() #it will show label in the plot
plt.show() #will draw graph

# %%
#this will be another example of cricket data vizualization
players=["dhoni","virat","rohit","sir jadeja"]
scores=[120,140,180,89]

#now plotting it
plt.xlabel('players')
plt.ylabel('scores')
plt.bar(players,scores,label= "2020 score of indian cricket team")
plt.grid(color='green')
plt.legend()
plt.show()
